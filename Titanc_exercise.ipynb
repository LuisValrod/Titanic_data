# %% [markdown]
# # Titanic

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Load Dataset Titanic and check NaN values

# %%
df = sns.load_dataset('Titanic')
df.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# ### Drop column deck since most of the values are NaN

# %%
df = df.drop(columns=['deck'])

# %% [markdown]
# ### Fill NaN values in age with median

# %%
median_age = df['age'].median()
df['age'] = df['age'].fillna(median_age)

# %% [markdown]
# ### Check NaN values in embark_town

# %%
df[df['embark_town'].isna()]
# Out:
#      survived  pclass     sex   age  sibsp  parch  fare embarked  class  \
# 61          1       1  female  38.0      0      0  80.0      NaN  First
# 829         1       1  female  62.0      0      0  80.0      NaN  First
#
#        who  adult_male embark_town alive  alone
# 61   woman       False         NaN   yes   True
# 829  woman       False         NaN   yes   True

# %% [markdown]
# ### Check duplicates

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886     True
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %% [markdown]
# ### Drop Duplicates

# %%
df = df.drop_duplicates()
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.2500        S  Third
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 885         0       3  female  39.0      0      5  29.1250        Q  Third
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 888         0       3  female  28.0      1      2  23.4500        S  Third
# 889         1       1    male  26.0      0      0  30.0000        C  First
# 890         0       3    male  32.0      0      0   7.7500        Q  Third
#
#        who  adult_male  embark_town alive  alone
# 0      man        True  Southampton    no  False
# 1    woman       False    Cherbourg   yes  False
# 2    woman       False  Southampton   yes   True
# 3    woman       False  Southampton   yes  False
# 4      man        True  Southampton    no   True
# ..     ...         ...          ...   ...    ...
# 885  woman       False   Queenstown    no  False
# 887  woman       False  Southampton   yes   True
# 888  woman       False  Southampton    no  False
# 889    man        True    Cherbourg   yes   True
# 890    man        True   Queenstown    no   True
#
# [775 rows x 14 columns]

# %% [markdown]
# ### Rename columns

# %%
df.rename(columns={'sibsp':'Siblings and Spouses', 'parch': 'Parents or children'}, inplace=True)
df
# Out:
#      survived  pclass     sex   age  relatives  Parents or children     fare  \
# 0           0       3    male  22.0          1                    0   7.2500
# 1           1       1  female  38.0          1                    0  71.2833
# 2           1       3  female  26.0          0                    0   7.9250
# 3           1       1  female  35.0          1                    0  53.1000
# 4           0       3    male  35.0          0                    0   8.0500
# ..        ...     ...     ...   ...        ...                  ...      ...
# 885         0       3  female  39.0          0                    5  29.1250
# 887         1       1  female  19.0          0                    0  30.0000
# 888         0       3  female  28.0          1                    2  23.4500
# 889         1       1    male  26.0          0                    0  30.0000
# 890         0       3    male  32.0          0                    0   7.7500
#
#     embarked  class    who  adult_male  embark_town alive  alone  \
# 0          S  Third    man        True  Southampton    no  False
# 1          C  First  woman       False    Cherbourg   yes  False
# 2          S  Third  woman       False  Southampton   yes   True
# 3          S  First  woman       False  Southampton   yes  False
# 4          S  Third    man        True  Southampton    no   True
# ..       ...    ...    ...         ...          ...   ...    ...
# 885        Q  Third  woman       False   Queenstown    no  False
# 887        S  First  woman       False  Southampton   yes   True
# 888        S  Third  woman       False  Southampton    no  False
# 889        C  First    man        True    Cherbourg   yes   True
# 890        Q  Third    man        True   Queenstown    no   True
#
#      fare_percentage  total_fare
# 0           0.026821  27030.7623
# 1           0.263712  27030.7623
# 2           0.029318  27030.7623
# 3           0.196443  27030.7623
# 4           0.029781  27030.7623
# ..               ...         ...
# 885         0.107748  27030.7623
# 887         0.110985  27030.7623
# 888         0.086753  27030.7623
# 889         0.110985  27030.7623
# 890         0.028671  27030.7623
#
# [775 rows x 16 columns]

# %% [markdown]
# ### Describe to have a summary info

# %%
df.describe()
# Out:
#          survived      pclass         age   relatives       parch        fare
# count  775.000000  775.000000  775.000000  775.000000  775.000000  775.000000
# mean     0.412903    2.246452   29.581187    0.529032    0.420645   34.878403
# std      0.492674    0.853574   13.766359    0.990326    0.840565   52.408474
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    1.000000   21.000000    0.000000    0.000000    8.050000
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   15.900000
# 75%      1.000000    3.000000   36.000000    1.000000    1.000000   34.197900
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# ### Average fare and age per class

# %%
average_fare_age_per_class = df.groupby('pclass')[['fare', 'age']].mean()
average_fare_age_per_class
# Out:
#              fare        age
# pclass
# 1       85.675199  36.921048
# 2       21.889279  29.791646
# 3       13.588850  25.651297

# %% [markdown]
# ### New column showing the fare as a percentage of total

# %%
total_fare = df['fare'].sum()
df['fare_percentage'] = (df['fare']/total_fare)*100
df['total_fare'] = total_fare 
df
# Out:
#      survived  pclass     sex   age  relatives  parch     fare embarked  \
# 0           0       3    male  22.0          1      0   7.2500        S
# 1           1       1  female  38.0          1      0  71.2833        C
# 2           1       3  female  26.0          0      0   7.9250        S
# 3           1       1  female  35.0          1      0  53.1000        S
# 4           0       3    male  35.0          0      0   8.0500        S
# ..        ...     ...     ...   ...        ...    ...      ...      ...
# 885         0       3  female  39.0          0      5  29.1250        Q
# 887         1       1  female  19.0          0      0  30.0000        S
# 888         0       3  female  28.0          1      2  23.4500        S
# 889         1       1    male  26.0          0      0  30.0000        C
# 890         0       3    male  32.0          0      0   7.7500        Q
#
#      class    who  adult_male  embark_town alive  alone  fare_percentage  \
# 0    Third    man        True  Southampton    no  False         0.026821
# 1    First  woman       False    Cherbourg   yes  False         0.263712
# 2    Third  woman       False  Southampton   yes   True         0.029318
# 3    First  woman       False  Southampton   yes  False         0.196443
# 4    Third    man        True  Southampton    no   True         0.029781
# ..     ...    ...         ...          ...   ...    ...              ...
# 885  Third  woman       False   Queenstown    no  False         0.107748
# 887  First  woman       False  Southampton   yes   True         0.110985
# 888  Third  woman       False  Southampton    no  False         0.086753
# 889  First    man        True    Cherbourg   yes   True         0.110985
# 890  Third    man        True   Queenstown    no   True         0.028671
#
#      total_fare
# 0    27030.7623
# 1    27030.7623
# 2    27030.7623
# 3    27030.7623
# 4    27030.7623
# ..          ...
# 885  27030.7623
# 887  27030.7623
# 888  27030.7623
# 889  27030.7623
# 890  27030.7623
#
# [775 rows x 16 columns]

# %% [markdown]
# ### How many survivors were male?

# %%
df[(df['survived'] == 1) & (df['sex'] == 'male')].shape[0]
# Out:
# 104

# %%
((df['survived'] == 1) & (df['sex'] == 'male')).sum()
# Out:
# 104

# %%
df[(df['survived'] == 1) & (df['sex'] == 'male')].count()
# Out:
# survived           104
# pclass             104
# sex                104
# age                104
# relatives          104
# parch              104
# fare               104
# embarked           104
# class              104
# who                104
# adult_male         104
# embark_town        104
# alive              104
# alone              104
# fare_percentage    104
# total_fare         104
# dtype: int64

# %% [markdown]
# ### How Many Survivors were female?

# %%
df[(df['survived'] == 1) & (df['sex'] == 'female')].shape[0]
# Out:
# 216

# %% [markdown]
# ### How many survivors were female compared to male?

# %%
male_survivors = df[(df['survived'] == 1) & (df['sex'] == 'male')].shape[0]
female_survivors = df[(df['survived'] == 1) & (df['sex'] == 'female')].shape[0]
difference = female_survivors - male_survivors
survivors = pd.DataFrame({'Male Survivors': male_survivors,
                       'Female Survivors': female_survivors,
                       'Difference': difference},
                        index=['Counts'])
survivors
# Out:
#         Male Survivors  Female Survivors  Difference
# Counts             104               216         112

# %% [markdown]
# ### Survivors per class

# %%
df[(df['survived'] == 1) & (df['class'] == 'First')].shape[0]
# Out:
# 133

# %%
df[(df['survived'] == 1) & (df['class'] == 'Second')].shape[0]
# Out:
# 83

# %%
df[(df['survived'] == 1) & (df['class'] == 'Third')].shape[0]
# Out:
# 104

# %%
total_survivors = df[df['survived'] == 1].shape[0] 
total_survivors
# Out:
# 320

# %%
first_class_survivors = df[(df['survived'] == 1) & (df['class'] == 'First')].shape[0]
second_class_survivors = df[(df['survived'] == 1) & (df['class'] == 'Second')].shape[0]
third_class_survivors = df[(df['survived'] == 1) & (df['class'] == 'Third')].shape[0]
survivors_class = pd.DataFrame({'Firs_Class': first_class_survivors,
                                'Second_Class': second_class_survivors,
                                'Third_Class': third_class_survivors},
                               index=['Counts'])
survivors_class
# Out:
#         Firs_Class  Second_Class  Third_Class
# Counts         133            83          104

# %% [markdown]
# ### Survivor per pclass

# %%
first_class_survivors = df[(df['survived'] == 1) & (df['pclass'] == 1)].shape[0]
second_class_survivors = df[(df['survived'] == 1) & (df['pclass'] == 2)].shape[0]
third_class_survivors = df[(df['survived'] == 1) & (df['pclass'] == 3)].shape[0]
survivors_class = pd.DataFrame({'Firs_Class': first_class_survivors,
                                'Second_Class': second_class_survivors,
                                'Third_Class': third_class_survivors},
                               index=['Counts'])
survivors_class
# Out:
#         Firs_Class  Second_Class  Third_Class
# Counts         133            83          104

# %% [markdown]
# ### Survivors per age

# %%
child_survivors = df[(df['survived'] == 1) & (df['age'] < 18)].shape[0]
young_adult_survivors = df[(df['survived'] == 1) & (df['age'] >= 18) & (df['age'] <= 30)].shape[0]
mid_adult_survivors = df[(df['survived'] == 1) & (df['age'] >= 31) & (df['age'] <= 60)].shape[0]
old_adult_survivors = df[(df['survived'] == 1) & (df['age'] > 60)].shape[0]
survivors_age = pd.DataFrame({'18<': child_survivors,
                                '18 - 30': young_adult_survivors,
                                '31 - 60': mid_adult_survivors,
                                '60<': old_adult_survivors },
                               index=['Survivors per age'])
survivors_age
# Out:
#                    18<  18 - 30  31 - 60  60<
# Survivors per age   60      139      116    5

# %%
correlation_matrix = df[['age', 'fare', 'survived', 'pclass']].corr()
correlation_matrix
# Out:
#                age      fare  survived    pclass
# age       1.000000  0.092503 -0.078114 -0.342745
# fare      0.092503  1.000000  0.247159 -0.554649
# survived -0.078114  0.247159  1.000000 -0.331388
# pclass   -0.342745 -0.554649 -0.331388  1.000000

# %%
survivors = df[df['survived']==1].shape[0]
total= df.shape[0]
percentage_survivors = f"{round((survivors/total) * 100, 2)}%"
percentage_s = pd.Series(percentage_survivors, index=['% Survivors'])
percentage_s
# Out:
# % Survivors    41.29%
# dtype: object

# %% [markdown]
# ### Survivors Alone

# %%
alone_survivors = df[(df['survived'] == 1) & (df['alone'])].shape[0]
not_alone_survivors = df[(df['survived'] == 1) & (df['alone']==False)].shape[0]
alone_survivors = pd.DataFrame({'Lonely Survivors': alone_survivors,
                                '
